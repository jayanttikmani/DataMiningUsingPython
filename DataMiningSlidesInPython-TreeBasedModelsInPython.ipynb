# %% [markdown]
# #### Tree Based Models In Python

# %%
import pandas as pd
#Loading Dataset in DataFrame
Hitters = pd.DataFrame.from_csv('C://Users//Jayant//Desktop//sem2//DMPA//PythonSlides//Hitters.csv', index_col=None)
Hitters.columns.values
# Out:
# array(['Unnamed: 0', 'AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks',
#        'Years', 'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks',
#        'League', 'Division', 'PutOuts', 'Assists', 'Errors', 'Salary',
#        'NewLeague'], dtype=object)

# %%
import numpy as np
Hitters = Hitters.dropna(axis=0, how='any')
Hitters['lnSalary'] = np.log(Hitters['Salary'])

# %%
#histogram of salary
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
init_notebook_mode()

x = Hitters['Salary'].values.tolist()
data = [go.Histogram(x=x)]

iplot(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# ...

# %%
#histogram of lnsalary
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
init_notebook_mode()

x = Hitters['lnSalary'].values.tolist()
data = [go.Histogram(x=x)]

iplot(data)
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.20.5
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
#preparing dependent and independent variables for regression tree
X = Hitters[["Years","Hits"]]
y = Hitters['lnSalary']

# %%
#Fitting Regression Tree Model
from sklearn import tree
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X,y)

# %%
#Plotting Trees
import pydotplus 
from IPython.display import Image  
dot_data = tree.export_graphviz(clf, out_file=None, 
                        feature_names=X.columns.values,  
                        filled=True, rounded=True,  
                        special_characters=True,
                               max_depth=3)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
#Validation Set Approach
# Out:
#   File "<ipython-input-14-355b4aa3d43c>", line 1
#     dot -Tpdf hitters.dot -o hitters.pdf
#                     ^
# SyntaxError: invalid syntax

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)

# %%
import pydotplus
from IPython.display import Image  
dot_data = tree.export_graphviz(clf, out_file=None, 
                        feature_names=iris.feature_names,  
                        class_names=iris.target_names,  
                        filled=True, rounded=True,  
                        special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())
